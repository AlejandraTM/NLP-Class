# %% [markdown]
# <center><h1> Clase 2. NLP </h1></center>
# <center><h3> 25 de febrero del 2021 </h3></center>

# %% [markdown]
# # Repaso de Python
#
# ### 🤪 Bucles con muchas variables

# %%
palabra="Pinche Viviana, no sabía esto"
a=[]
for i,_ in enumerate(palabra):
    a.append(_)

# %%
print(a)
# Out:
# ['P', 'i', 'n', 'c', 'h', 'e', ' ', 'V', 'i', 'v', 'i', 'a', 'n', 'a', ',', ' ', 'n', 'o', ' ', 's', 'a', 'b', 'í', 'a', ' ', 'e', 's', 't', 'o']

# %%
[n for n in range(5,15) if n%2==0]
# Out:
# [6, 8, 10, 12, 14]

# %% [markdown]
# ### 😜 Diccionarios

# %%
mi_dic={}

# %%
mi_dic['verde']='green'

# %%
mi_dic
# Out:
# {'verde': 'green'}

# %% [markdown]
# ### 😝 Funciones Lambda

# %%
import pandas as pd #Maneja datos tabulados

# %%
data=pd.DataFrame([["Lucas",1],["Negra",2],["Revolcon",3],["Bobby",4]])
data.columns=["Perritos","Orden de llegada"]
data
# Out:
#    Perritos  Orden de llegada
# 0     Lucas                 1
# 1     Negra                 2
# 2  Revolcon                 3
# 3     Bobby                 4

# %%
data['Perritos'].apply(lambda perro:"Hijo "+perro.upper())
# Out:
# 0       Hijo LUCAS
# 1       Hijo NEGRA
# 2    Hijo REVOLCON
# 3       Hijo BOBBY
# Name: Perritos, dtype: object

# %% [markdown]
# ### 🤗 Instalar librerías en el Notebook

# %%
! pwd
# Out:
# /home/alejandratmanotas/Documentos/GitHub/NLP-Class-2021-1

# %%
! pip install fuzzywuzzy

# %% [markdown]
# # Flujo de datos (pipeline)
#
# * Adquisición de datos
# * Limpieza de datos
# * Pre-prosesamiento
# * Feature Ingeniering (Creación de características): Crea los indicadores del proyecto y se convierten en un formato que entienda el algoritmo
# * Modelo
# * Evalueción de rendimiento
# * Modelo en producción
# * Vigilancia y actualización

# %% [markdown]
# ### 🛰️ Conjunto de datos abiertos
#
# * GitHub
# * [Kagle](https://www.kaggle.com/competitions)
# * Dataset Research

# %% [markdown]
# ## 1. Adquisición de datos

# %% [markdown]
# ###  📑 Archivos .csv

# %%
import pandas as pd

# %%
df=pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.read_csv? #Saber que puede hacer esta librería

# %%
df.species.str.cat(sep="  ")
# Out:
# 'setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  setosa  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolor  versicolo
# ...

# %% [markdown]
# ###  📑 Archivos .txt

# %%
with open("grabacion.txt") as archivo: # With no corrompe el archivo. Si no usan Linux o Mac usar encoding="utf-8"
    data=archivo.read()                # dentro del paréntesis del open

# %%
print(data)
# Out:
# © - Derechos Reservados: La presente obra, y todos sus contenidos, se encuentran protegidos por la normativa nacional e internacional vigente sobre propiedad Intelectual, por lo tanto su utilización parcial o total, reproducción, comunicación pública, transformación, distribución, alquiler, préstamo público e importación, total o parcial, en todo o en parte, en formato impreso o digital y en cualquier formato conocido o por conocer, se encuentran prohibidos, y solo serán lícitos en la medida en que se cuente con la autorización previa y expresa por escrito de la Fundación Universitaria Konrad Lorenz. Así mismo, de acuerdo con la normativa referente al habeas data, la utilización de la imagen de las personas, docentes o estudiantes, sin su previa autorización está expresamente prohibida. En caso de incumplirse con lo mencionado, se procederá de conformidad con los reglamentos de la Institución, sin perjuicio de las demás acciones legales aplicables.

# %% [markdown]
# ###  📑 Archivos .json

# %%
import json

# %%
with open("sistemas_operativos.json") as archivo2:
    data=json.load(archivo2)

# %%
data
# Out:
# [{'Name': 'Debian',
#   'Version': '9',
#   'Install': 'apt',
#   'Owner': 'SPI',
#   'Kernel': '4.9'},
#  {'Name': 'Ubuntu',
#   'Version': '17.10',
#   'Install': 'apt',
#   'Owner': 'Canonical',
#   'Kernel': '4.13'},
#  {'Name': 'Fedora',
#   'Version': '26',
#   'Install': 'dnf',
#   'Owner': 'Red Hat',
#   'Kernel': '4.13'},
#  {'Name': 'CentOS',
#   'Version': '7',
#   'Install': 'yum',
#   'Owner': 'Red Hat',
#   'Kernel': '3.10'},
#  {'Name': 'OpenSUSE',
#   'Version': '42.3',
#   'Install': 'zypper',
#   'Owner': 'Novell',
#   'Kernel': '4.4'},
#  {'Name': 'Arch Linux',
#   'Version': 'Rolling Release',
#   'Install': 'pacman',
#   'Owner': 'SPI',
#   'Kernel': '4.13'},
#  {'Name': 'Gentoo',
#   'Version': 'Rolling Release',
#   'Install': 'emerge',
#   'Owner': 'Gentoo Foundation',
#   'Kernel': '4.12'}]

# %%
#Pasarlo a forma tabular
from pandas.io.json import json_normalize

# %%
json_normalize(data)
# Out:
# <ipython-input-36-1c283760bfe1>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(data)
#          Name          Version Install              Owner Kernel
# 0      Debian                9     apt                SPI    4.9
# 1      Ubuntu            17.10     apt          Canonical   4.13
# 2      Fedora               26     dnf            Red Hat   4.13
# 3      CentOS                7     yum            Red Hat   3.10
# 4    OpenSUSE             42.3  zypper             Novell    4.4
# 5  Arch Linux  Rolling Release  pacman                SPI   4.13
# 6      Gentoo  Rolling Release  emerge  Gentoo Foundation   4.12

# %% [markdown]
# ### 🗂️ Archivo tipo .zip

# %%
import os
from zipfile import ZipFile

# %%
direccion="~/home/alejandratmanotas/Documentos/GitHub/NLP-Class-2021-1"

# %%
with ZipFile("astrok.zip") as archivo3:
    archivo3.extractall()

# %%
import shutil
shutil.rmtree('__MACOSX')

# %%
for archivo3 in os.walk("astrok"):
    print(archivo)
# Out:
# <_io.TextIOWrapper name='grabacion.txt' mode='r' encoding='UTF-8'>

# %%
for raiz, dirs, archivos in os.walk("astrok"):
    for a in archivos:
        print(a)
# Out:
# Perseverance.txt
# Conjucio╠ün.txt
# La muerte de las estrellas.txt

# %% [markdown]
# ### 📋 Word

# %%
! pip install python-docx

# %%
import docx

# %%
# Lectura de testos planos en word
documento = docx.Document("Colombia.docx")

# %%
[print(p.text) for p in documento.paragraphs]
# Out:
# Colombia
#
# Colombia, oficialmente República de Colombia, es un país soberano situado en la región noroccidental de América del Sur, que se constituye en un estado unitario, social y democrático d
# e derecho cuya forma de gobierno es presidencialista. Es una república organizada políticamente en 32 departamentos descentralizados y el Distrito Capital de Bogotá, sede del Gobierno Nacional.
# [None, None, None, None, None, None, None]

# %%
# Lectura de tablas en word
tabla=documento.tables[0]
tabla

# %%
data=[]

for i,fila in enumerate(tabla.rows):
    f=[celda.text for celda in fila.cells]
    data.append(f)
    
df=pd.DataFrame(data)   
df
# Out:
#                                   0             1            2
# 0                            REGION  DEPARTAMENTO    MUNICIPIO
# 1   Región Eje Cafetero - Antioquia     Antioquia     Medellín
# 2   Región Eje Cafetero - Antioquia     Antioquia    Abejorral
# 3   Región Eje Cafetero - Antioquia     Antioquia     Abriaquí
# 4   Región Eje Cafetero - Antioquia     Antioquia   Alejandría
# 5   Región Eje Cafetero - Antioquia     Antioquia        Amagá
# 6   Región Eje Cafetero - Antioquia     Antioquia       Amalfi
# 7   Región Eje Cafetero - Antioquia     Antioquia        Andes
# 8   Región Eje Cafetero - Antioquia     Antioquia  Angelópolis
# 9   Región Eje Cafetero - Antioquia     Antioquia    Angostura
# 10  Región Eje Cafetero - Antioquia     Antioquia        Anorí

# %% [markdown]
# ### 📊 Excel

# %%
# Import pandas
data=pd.read_excel("hoja.xlsx")
data.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
# Lectura de segunda hoja
data2=pd.read_excel("hoja.xlsx",sheet_name=1)
data2
# Out:
#       Hoja 2 Unnamed: 1
# 0       Días     Número
# 1      Lunes          1
# 2     Martes          2
# 3  Miércoles          3
# 4     Jueves          4
# 5    Viernes          5
# 6     Sábado          6
# 7    Domingo          7

# %%
#Adaptación de la url para poder dejar el archivo descargable
url="https://docs.google.com/spreadsheets/d/1O8k9ZBaHSPbw_8IgE-jxmVE8FkMWimr6dZPuKhAT2hM/edit#gid=0"
new_url=url.rsplit("/",1)[0]+"/gviz/tq?tqx=out:csv"
new_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1O8k9ZBaHSPbw_8IgE-jxmVE8FkMWimr6dZPuKhAT2hM/gviz/tq?tqx=out:csv'

# %%
#Lectura del archivo
data=pd.read_csv(new_url)
data
# Out:
#      Español    English
# 0      Lunes     Monday
# 1     Martes    Tuesday
# 2  Miércoles  Wednesday
# 3     Jueves   Thursday
# 4    Viernes     Friday

# %% [markdown]
# ### 📄 Archivos PDF

# %%
! pip install PyMuPD
# Out:
# ERROR: Could not find a version that satisfies the requirement PyMuPD (from versions: none)
# ERROR: No matching distribution found for PyMuPD

# %%
import fitz

# %%
documento=fitz.open("cien.pdf")

# %%
print("Número de páginas: ", documento.pageCount)
print("Metados: ", documento.metadata)
# Out:
# Número de páginas:  1
# Metados:  {'format': 'PDF 1.3', 'title': 'cien', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Pages', 'producer': 'macOS Version 10.15.6 (Build 19G2021) Quartz PDFContext', 'creationDate': "D:20200822062639Z00'00'", 'modDate': "D:20200822062639Z00'00'", 'trapped': '', 'encryption': None}

# %%
pagina = documento.loadPage(0)
texto = pagina.getText("text")
print(texto)
# Out:
# Cien años de soledad
# Muchos años después, frente al pelotón de fusilamiento, el coronel Aureliano Buendía había de
# recordar aquella tarde remota en que su padre lo llevó a conocer el hielo. Macondo era entonces
# una aldea de veinte casas de barro y cañabrava construidas a la orilla de un río de aguas diáfanas
# que se precipitaban por un lecho de piedras pulidas, blancas y enormes como huevos
# prehistóricos. El mundo era tan reciente, que muchas cosas carecían de nombre, y para
# mencionarlas había que señalarías con el dedo. Todos los años, por el mes de marzo, una familia
# de gitanos desarrapados plantaba su carpa cerca de la aldea, y con un grande alboroto de pitos y
# timbales daban a conocer los nuevos inventos. Primero llevaron el imán. Un gitano corpulento, de
# barba montaraz y manos de gorrión, que se presentó con el nombre de Melquiades, hizo una
# truculenta demostración pública de lo que él mismo llamaba la octava maravilla de los sabios
# ...

# %% [markdown]
# ###   🎞️ Archivos de imagen

# %%
import pytesseract
from pytesseract import image_to_string
from PIL import Image

# %%
Image.open("discretas.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1189x516 at 0x7EFD232FC430>

# %%
texto = image_to_string(Image.open("discretas.png"))
print(texto)
# Out:
# {ss
#
# Ces: al curse de Za
#
# We. Diseretas
#
# al

# %% [markdown]
# ## 2. Aumento de datos
#
# * Voltear imágenes
# * Agregar ruido
# * Sinónimos y antónimos
# * Traducción ida y vuelta
# * Agregar ruido al texto
#
# Librería en python https://github.com/makcedward/nlpaug
